# %%
import base64
from dotenv import load_dotenv
from openai import OpenAI
import os

# Load environment variables from .env file
load_dotenv()

# Access the OpenAI API key
openai_api_key = os.getenv("OPENAI_API_KEY")

# Verify that the key was loaded
if openai_api_key:
    print("OpenAI API key loaded successfully.")
else:
    print("Error: OpenAI API key not found. Check your .env file.")
    exit(1)
# Out:
# OpenAI API key loaded successfully.

# %%
# Initialize the OpenAI client with the API key
client = OpenAI(api_key=openai_api_key)
prompt = """
A children's book drawing of a veterinarian using a stethoscope to 
listen to the heartbeat of a baby pug.
"""

result = client.images.generate(
    model="gpt-image-1",
    prompt=prompt
)

image_base64 = result.data[0].b64_json
image_bytes = base64.b64decode(image_base64)

# Save the image to a file
with open("pug.png", "wb") as f:
    f.write(image_bytes)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[3], line 8
#       2 client = OpenAI(api_key=openai_api_key)
#       3 prompt = """
#       4 A children's book drawing of a veterinarian using a stethoscope to
#       5 listen to the heartbeat of a baby pug.
#       6 """
# ----> 8 result = client.images.generate(
#       9     model="gpt-image-1",
#      10     prompt=prompt
#      11 )
#      13 image_base64 = result.data[0].b64_json
#      14 image_bytes = base64.b64decode(image_base64)
#
# File ~/.cache/pypoetry/virtualenvs/pugchat-pUQl0kMl-py3.11/lib/python3.11/site-packages/openai/resources/images.py:322, in Images.generate(self, prompt, background, model, moderation, n, output_compression, output_format, quality, response_format, size, style, user, extra_headers, extra_query, extra_body, timeout)
#     228 def generate(
#     229     self,
#     230     *,
#    (...)    251     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     252 ) -> ImagesResponse:
#     253     """
#     254     Creates an image given a prompt.
#     255     [Learn more](https://platform.openai.com/docs/guides/images).
#    (...)    320       timeout: Override the client-level default timeout for this request, in seconds
#     321     """
# --> 322     return self._post(
#     323         "/images/generations",
#     324         body=maybe_transform(
#     325             {
#     326                 "prompt": prompt,
#     327                 "background": background,
#     328                 "model": model,
#     329                 "moderation": moderation,
#     330                 "n": n,
#     331                 "output_compression": output_compression,
#     332                 "output_format": output_format,
#     333                 "quality": quality,
#     334                 "response_format": response_format,
#     335                 "size": size,
#     336                 "style": style,
#     337                 "user": user,
#     338             },
#     339             image_generate_params.ImageGenerateParams,
#     340         ),
#     341         options=make_request_options(
#     342             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     343         ),
#     344         cast_to=ImagesResponse,
#     345     )
#
# File ~/.cache/pypoetry/virtualenvs/pugchat-pUQl0kMl-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)   1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.cache/pypoetry/virtualenvs/pugchat-pUQl0kMl-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1034, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1031             err.response.read()
#    1033         log.debug("Re-raising status error")
# -> 1034         raise self._make_status_error_from_response(err.response) from None
#    1036     break
#    1038 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: Error code: 403 - {'error': {'message': 'Your organization must be verified to use the model `gpt-image-1`. Please go to: https://platform.openai.com/settings/organization/general and click on Verify Organization. If you just verified, it can take up to 15 minutes for access to propagate.', 'type': 'invalid_request_error', 'param': None, 'code': None}}

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
